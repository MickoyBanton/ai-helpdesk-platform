# %%
! pip install tensorflow
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\micko\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import re
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# %%
helpdesk_ticket_data = pd.read_csv("it_helpdesk_tickets_500.csv")
helpdesk_ticket_data = helpdesk_ticket_data.drop_duplicates(subset=["description"])

# %%
helpdesk_ticket_data = helpdesk_ticket_data.dropna(subset="description")
helpdesk_ticket_data = helpdesk_ticket_data.dropna(subset=["category"])

# %%
helpdesk_ticket_data["description"] = helpdesk_ticket_data["description"].str.lower()

# %%
def clean_text(t):
    t = re.sub(r"[^a-zA-Z0-9 ]", " ", t)
    t = re.sub(r"\s+", " ", t)
    return t.strip()

helpdesk_ticket_data["description"] = helpdesk_ticket_data["description"].apply(clean_text)

# %%
le_cat = LabelEncoder()
helpdesk_ticket_data["category_label"] = le_cat.fit_transform(helpdesk_ticket_data["category"])

# %%
le_pri = LabelEncoder()
helpdesk_ticket_data["priority_label"] = le_pri.fit_transform(helpdesk_ticket_data["priority"])

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(helpdesk_ticket_data["description"])

X = tokenizer.texts_to_sequences(helpdesk_ticket_data["description"])
X = pad_sequences(X, maxlen=20)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, helpdesk_ticket_data["category_label"], test_size=0.2, random_state=42
)

# %%
helpdesk_ticket_data.head(10)
# Out:
#     ticket_id                                      description  \
# 0           1                  wifi disconnects intermittently
# 1           2  system slows down after installing new software
# 2           3                       password reset not working
# 3           4                 software update fails repeatedly
# 5           6                     network speed extremely slow
# 6           7               computer won t boot after shutdown
# 7           8                 ethernet connection not detected
# 9          10                  two factor authentication fails
# 11         12               program freezes when saving a file
# 12         13                  laptop overheats and shuts down
#
#           category priority  category_label  priority_label
# 0          Network      Low               2               2
# 1         Software     High               3               1
# 2   Account Access   Medium               0               3
# ...
